# %%
'''
#--------------
#BOZZA PROGETTO
#--------------
#Machine Learning (apprendere dai mondiali passati)
#ranking fifa
#fifa 18 stats
#quote snai
#partite ultimo anno
#allenatore
#situazione economica
#twitter
#--------------
#DATI
#--------------
https://www.kaggle.com/thec03u5/fifa-18-demo-player-dataset#CompleteDataset.csv
https://www.kaggle.com/tadhgfitzgerald/fifa-international-soccer-mens-ranking-1993now
https://raw.githubusercontent.com/kafagy/fifa-FUT-Data/master/FIFA18.csv
---------------
TODO
---------------
debug codice
inserire i dati
regolare i parametri
twitter
machine learning
'''
import csv
from difflib import SequenceMatcher

# %%
class Player():
    def __init__(self):
        self.stats = {"overall" : None, "pace" : None, "shooting" : None, "passing" : None, "dribbling" : None, "defending" : None, "phisichal" : None} #Various stats between 0 and 100   ->
        self.name = None  # Player's name
        self.team = None  # Player's team
        self.age = None  # Player's age
        self.nAccidents = None  # Number of the player's accidents in his career
        self.position = None  # Position covered by the player
        self.regular = None  # It defines if the player is a regular or not
        
    def to_string(self):
        return "name: " + str(self.name) + " overall: " + str(self.stats.get("overall"))

# %%
class Match():  
    def __init__(self, team1, team2):
        self.teams = [team1, team2]   

    def result_calculator(self):  # if a team win return this team else return None
        x=None # ranking moltiplicator
        y=None # power moltiplicatpor
        winProbability=(team1.ranking*x + team1.power*y)-(team2.ranking*x + team2.power*y)
        delta=None  # the maximum difference for the draw
        if abs(winProbability)<delta:
            return None
        if winProbability>0:
            return team1
        else:
            return team2

# %%
class WorldCup():
    def __init__(self, year, groups):
        self.year = year   # Year in which lived the competition
        self.groups = groups  # World cup initial groups
        self.knockout_phase = [[]for i in range(5)]
        
    def calculate_match_list(self):  # Calculate the match list for every group
        for group in self.groups:
            group.match_list()
    
    def pre_rounds(self): # Initalize the knockout phase
        for x in range (0,len(self.groups)):
            for i in range (0,len(self.group.team)-1):
                index=i
                for j in range(i, len(self.groups.teams)):
                    if (self.groups[x].score[j]<self.groups[x].score[index]):
                        index=j  

                tmp=self.groups[x].team[index]
                self.groups[x].team[index] = self.groups[x].team[index]
                self.groups[x].team[index]= tmp
        
        self.knockout_phase[0][0]=self.groups[0].team[0]
        self.knockout_phase[0][1]=self.groups[1].team[1]
        
        self.knockout_phase[0][2]=self.groups[2].team[0]
        self.knockout_phase[0][3]=self.groups[3].team[1]
        
        self.knockout_phase[0][4]=self.groups[1].team[0]
        self.knockout_phase[0][5]=self.groups[0].team[1]
        
        self.knockout_phase[0][6]=self.groups[3].team[0]
        self.knockout_phase[0][7]=self.groups[2].team[1]
        
        self.knockout_phase[0][8]=self.groups[4].team[0]
        self.knockout_phase[0][9]=self.groups[5].team[1]
        
        self.knockout_phase[0][10]=self.groups[6].team[0]
        self.knockout_phase[0][11]=self.groups[7].team[1]
        
        self.knockout_phase[0][12]=self.groups[5].team[0]
        self.knockout_phase[0][13]=self.groups[4].team[1]
        
        self.knockout_phase[0][14]=self.groups[7].team[0]
        self.knockout_phase[0][15]=self.groups[6].team[1]
        
    def rounds(self): # Do the knockout phase
        for i in range(len(self.knockout_phase)):
            pos = 0
            for j in range(0,len(self.knockout_phase[i]), 2):
                knockout_phase[i][pos].append(Match(knockout_phase[j], knockout_phase[j+1]).result_calculator())
                pos += 1
        


class Groups():
    def __init__(self, teams):
        self.teams = teams
        self.scores = [0, 0, 0, 0]
    
    def add_point(self, team, point=1): # Add a points to a specified team
        for i in range(len(self.teams)):
            if team == self.teams[i]:
                self.scores[i] += point
                return
        
    def match_list(self): # Calculates the scores
        for i in range(len(self.teams)):
            for k in range(len(self.teams) - i - 1):
                winner = Match(self.teams[i], self.teams[i+k +1]).result_calculator()
                if winner is None:
                    self.add_point(self.teams[i])
                    self.add_point(self.teams[i+k +1])
                else:
                    self.add_point(winner, 3)

# %%
class DataLoader():
    def __init__(self):
        self.players = []
        self.columns = []
        self.teams = []
        
    def load_teams(self, filename, players): # Not working well (useless)
#         from os import listdir
#         from os.path import isfile, join
#         files = [f for f in listdir(path) if isfile(join(path, f))]
        self.columns = []
        first_line = True
        team_name = filename.replace(".csv", "")
        t = Team()
        t.name = team_name
        with open(filename) as f:
            reader = csv.reader(f, delimiter=',')
            for row in reader:
                if first_line:
                    self.columns = row
                    print("column: " + str(row[self.get_column("Overall")]))
                    first_line = False
                else:
                    player_name = row[self.get_column("Player")]
                    club = row[self.get_column("Club")]
                    t.reserve.append(self.get_player(player_name, players))
                    self.teams.append(t)
        return self.teams
    def get_player(self, name, players, delta = 0.6):
#         print(name)
        name = name.split(' ')[1]
        for player in players:
#             print(player.name)
            player_name = player.name
            if SequenceMatcher(None,player_name,name).ratio() > delta :
                print("Found " + name + " as " + player_name)
                return player
        print("Not found " + name + " as " + player_name)
        
    def load_teams2(self, path, players ): # Loads player in teams
        from os import listdir
        from os.path import isfile, join
        files = [f for f in listdir(path) if isfile(join(path, f))]
        for tmp_file in files:
            tmp_file = tmp_file.replace(".csv","")
            t = Team()
            t.name = tmp_file
            self.teams.append(t)
        for player in players:
            if self.is_player_in_team(player.name,path + player.team + ".csv"):
                self.add_to_team(player,player.team)
        for team in self.teams:
            team.clean_reserve()
        return self.teams
                
                
            
    def add_to_team(self, player, team_name):
        for team in self.teams:
            if team.name == team_name:
                team.reserve.append(player)
#         print("Failed to find team "+ team_name)
        
    def is_player_in_team(self, name, filename, delta=0.9):
        self.columns = []
        name = name.split(" ")
        name = name[-1]#(name[1] if len(name) > 1 else name[-1])
        first_line = True
        try:
            with open(filename) as f:
                reader = csv.reader(f, delimiter=',')
                for row in reader:
                    if first_line:
                        self.columns = row
    #                     print("column: " + str(row[self.get_column("Overall")]))
                        first_line = False
                    else:
                        player_name = row[self.get_column("Player")]
                        player_name = player_name.replace("(captain)", "")
                        player_name = player_name.split(" ")
                        if player_name[-1] == " ": 
                            player_name.pop(-1)
                        player_name = player_name[-1]#(name[1] if len(name) > 1 else name[-1])
                        if SequenceMatcher(None,player_name,name).ratio() > delta :
                            return True
        except IOError:
            pass
        return False
        
    def load_players(self, filename):  # Load player dataset from a csv
        self.columns = []
        first_line = True
        with open(filename) as f:
            reader = csv.reader(f, delimiter=',')
            for row in reader:
                if first_line:
                    self.columns = row
                    print("column: " + str(row[self.get_column("Overall")]))
                    first_line = False
                else:
                    p = Player()
                    p.name = row[self.get_column("Name")]
                    p.age = int(row[self.get_column("Age")])
                    p.stats["overall"] = int(row[self.get_column("Overall")])
                    p.team = row[self.get_column("Nationality")]
                    self.players.append(p)
                    '''
                    p.stats["pace"] = (int(row[self.get_column("Acceleration")]) + int(row[self.get_column("Sprint speed")])) / 2
                    p.stats["shooting"] = (int(row[self.get_column("Positioning")]) + int(row[self.get_column("Finishing")]) 
                                           + int(row[self.get_column("Long shots")])) / 3
                    p.stats["passing"] = (int(row[self.get_column("Crossing")]) + int(row[self.get_column("Vision")]) +
                                          int(row[self.get_column("Long passing")])) / 3
                    p.stats["dribbling"] = (int(row[self.get_column("Dribbling")]) + 
                                            int(row[self.get_column("Agility")]) +
                                            int(row[self.get_column("Balance")])) / 3
                    p.stats["defending"] = (int(row[self.get_column("Sliding tackle")]) + 
                                            int(row[self.get_column("Standing tackle")]) +
                                            int(row[self.get_column("Marking")])) / 3
                    p.stats["physical"] = (int(row[self.get_column("Strength")]) + 
                                           int(row[self.get_column("Aggression")])) / 2
                    '''
        return self.players

    def get_column(self, title):  # Find the corresponding column
        for i in range(len(self.columns)):
            if self.columns[i] == title:
                return i
        return -1

# %%
class Team():
    def __init__(self):
        self.name = None                # Team's name
        self.ranking = None             # Team's rank in FIFA
        self.regular = []             # Regular players of the team   ->
        self.reserve = []             # Reserve players of the team   ->
        self.trainer = None             # Team's trainer
        self.quotation = None           # Team's probablity of win
        self.economicalSituation = None  # Team's money. A richer team can grant more services for his players
        self.matchWon = 3               # Matches won by the team
        self.matchLose = 2              # Matches lost by the team
        self.matchDraw = 1              # Matches finished in a draw
        self.regularPower = 0
        self.reservePower = 0

    def regular_power_calculator(self):  # It computes regular players' power points. More powerful are the players, more points will have the team
        Total=0
        for i in self.regular:
            Total+=self.regular.stats.get("overall")
        self.regularPower=Total/len(self.regular)

    def reserve_power_calculator(self, reservePower):  # It computes reserve players' power points. More powerful are the players, more points will have the team
        Total = 0
        for i in self.reserve:
            Total += self.reserve.stats.get("overall")
        self.reservePower=Total/len(self.reserve)

    def power_calculator(self, power):
        x = None  # regular moltiplicator
        y = None  # reserve moltiplicator
        z = None  # trainer moltiplicator
        a = None  # quotation moltiplicator
        b = None  # economicalSituation moltiplicator
        power = self.regularPower*x + self.reservePower*y + self.trainerPower*z + (1/self.quotation)*a + self.economicalSituation*b

    def win_lose_draw_graphics(self):
        import matplotlib.mlab as mlab
        import matplotlib.pyplot as plt
        labels = ['WIN','LOSE','DRAW']
        y = [self.matchWon, self.matchLose, self.matchDraw]
        esplodi = [0, 0, 0] #explode identifica la distanza tra gli elementi
        fig, ax1 = plt.subplots()
        ax1.pie(y, labels=labels, explode=esplodi, autopct='%1.1f%%', startangle=90)
        ax1.set_title(self.name)
        fig.tight_layout()
        fig.show()
    
    def player_ordinator(self): #sort of player based on overoll (selection sort)
        for i in range (0,len(self.reserve)-1):
            index=i
            for j in range(i, len(self.reserve)):
                if (self.reserve[j].stats.get('overall')<self.reserve[index].stats.get('overall')):
                    index=j  
                
            tmp=self.reserve[index]
            self.reserve[index] = self.reserve[i]
            self.reserve[i] = tmp
        
    def regular_finder(self): #found the best eleven player of a team
        for i in range (0,11):
            self.regular[i]=self.reserve[i]
            for j in range(i,len(self.reserve)):
                self.reserve[i]=self.reserve[i+1]
                
    def to_string(self): # Returns a string containing all the players
        tmp = ""
        print(self.name + " has players: " + str(len(self.reserve)))
        for player in self.reserve:
            tmp += player.to_string() + "\n"
        return tmp
    
    def clean_reserve(self, summoned=23): # Remove abundant players and add dummy player if it's missing
        self.reserve = self.reserve[:summoned]
        if len(self.reserve) == 0:
            dummy = Player() # global average values
            dummy.name = "Dummy boy"
            dummy.age = 25
            dummy.stats["overall"] = 65
            dummy.team = self.name
            self.reserve.append(dummy)
        if len(self.reserve) < summoned:
            average_age = 0
            average_overall = 0
            for player in self.reserve:
                average_age += player.age
                average_overall += player.stats["overall"]
            average_age /= int(len(self.reserve))
            average_overall /= int(len(self.reserve))
            while len(self.reserve) < summoned:
                half_dummy = Player() # Team average values
                half_dummy.name = "Almost a dummy boy"
                half_dummy.age = average_age
                half_dummy.stats["overall"] = average_overall
                half_dummy.team = self.name
                self.reserve.append(half_dummy)

# %%
class Trainer():
    def __init__(self):
        self.name = None           # Trainer's name
        self.matchesWon = None    # Number if matches won
        self.matchesPlayed = None # Number of matches played
        
    def power_calculator(self, power):
        power=(self.matchesWon/self.matchesPlayed) * 100

# %%
'''
def loadFiles():
    from google.colab import files
    uploaded = files.upload()
    for fn in uploaded.keys():
    print('User uploaded file "{name}" with length {length} bytes'.format(
        name=fn, length=len(uploaded[fn])))
    return uploaded
'''
# Out:
# '\ndef loadFiles():\n    from google.colab import files\n    uploaded = files.upload()\n    for fn in uploaded.keys():\n    print(\'User uploaded file "{name}" with length {length} bytes\'.format(\n        name=fn, length=len(uploaded[fn])))\n    return uploaded\n'

# %%
def main():
    import pickle
    '''
    files = loadFiles()
    print("---------sad-----")
    print(files)
    '''
# #     Load data from csv
#     loader = DataLoader()
#     players = loader.load_players("../resources/CompleteDataset.csv")
# #     print(players[0])
#     teams = loader.load_teams2("../resources/nations/", players)
#     print(len(teams))
#     for team in teams:
#         print(team.to_string())
#     pickle.dump( teams, open( "../resources/saved_teams.p", "wb" ) )

# Load data from pickle
    teams = pickle.load( open( "../resources/saved_teams.p", "rb" ) )
    for team in teams:
        print(team.to_string())

# %%
main()
# Out:
# Serbia has players: 23
# name: N. Matić overall: 83
# name: B. Ivanović overall: 82
# name: S. Milinković-Savić overall: 80
# name: D. Tadić overall: 80
# name: A. Ljajić overall: 79
# name: F. Kostić overall: 78
# name: F. Kostić overall: 78
# name: A. Rukavina overall: 77
# name: A. Živković overall: 77
# name: L. Milivojević overall: 77
# name: S. Rajković overall: 75
# name: A. Mitrović overall: 75
# name: A. Prijović overall: 74
# name: M. Dmitrović overall: 74
# name: D. Tošić overall: 74
# name: U. Spajić overall: 73
# name: S. Mitrović overall: 73
# name: M. Veljković overall: 73
# name: M. Grujić overall: 71
# name: N. Milenković overall: 70
# name: U. Matić overall: 70
# name: L. Jović overall: 70
# name: V. Milinković-Savić overall: 69
#
# Japan has players: 23
# name: S. Kagawa overall: 83
# name: T. Inui overall: 78
# name: K. Honda overall: 78
# name: S. Okazaki overall: 77
# name: G. Haraguchi overall: 75
# name: H. Sakai overall: 75
# name: M. Yoshida overall: 75
# name: G. Shibasaki overall: 75
# name: G. Sakai overall: 74
# name: T. Usami overall: 74
# name: K. Nakamura overall: 73
# name: Y. Nagatomo overall: 73
# name: G. Shoji overall: 73
# name: E. Kawashima overall: 72
# name: Y. Endo overall: 72
# name: M. Higashiguchi overall: 72
# name: S. Nakamura overall: 71
# name: H. Yamaguchi overall: 70
# name: N. Ueda overall: 70
# name: K. Shibasaki overall: 70
# name: W. Endo overall: 69
# name: T. Makino overall: 69
# name: K. Nakamura overall: 69
#
# Brazil has players: 23
# name: Neymar overall: 92
# name: Thiago Silva overall: 88
# name: Coutinho overall: 86
# name: Miranda overall: 86
# name: Casemiro overall: 85
# name: Filipe Luís overall: 85
# name: Willian overall: 84
# name: Ederson overall: 83
# name: Marquinhos overall: 83
# name: Roberto Firmino overall: 83
# name: Douglas Costa overall: 82
# name: Taison overall: 82
# name: Fernandinho overall: 82
# name: Gabriel Jesus overall: 81
# name: Paulinho overall: 81
# name: Alisson overall: 80
# name: Fred overall: 80
# name: Renato Augusto overall: 80
# name: Danilo overall: 79
# name: Danilo overall: 78
# name: Danilo overall: 78
# name: Juan Jesus overall: 77
# name: Cássio overall: 75
#
# Sweden has players: 23
# name: E. Forsberg overall: 83
# name: M. Berg overall: 80
# name: V. Lindelöf overall: 79
# name: J. Guidetti overall: 78
# name: J. Guidetti overall: 78
# name: P. Jansson overall: 77
# name: J. Olsson overall: 76
# name: A. Ekdal overall: 76
# name: S. Larsson overall: 76
# name: J. Durmaz overall: 75
# name: M. Olsson overall: 75
# name: O. Toivonen overall: 75
# name: K. Johnsson overall: 75
# name: G. Svensson overall: 74
# name: S. Larsson overall: 74
# name: J. Johansson overall: 74
# name: R. Olsen overall: 74
# name: A. Johansson overall: 73
# name: E. Krafth overall: 73
# name: M. Lustig overall: 73
# name: K. Nordfeldt overall: 73
# name: N. Johansson overall: 73
# name: O. Hiljemark overall: 73
#
# Germany has players: 23
# name: T. Kroos overall: 90
# name: J. Boateng overall: 88
# name: M. Hummels overall: 88
# name: M. Özil overall: 88
# name: T. Müller overall: 86
# name: M. Reus overall: 86
# name: M. ter Stegen overall: 85
# name: I. Gündoğan overall: 85
# name: J. Draxler overall: 84
# name: S. Khedira overall: 84
# name: N. Süle overall: 83
# name: T. Werner overall: 82
# name: L. Goretzka overall: 82
# name: A. Rüdiger overall: 82
# name: K. Trapp overall: 82
# name: M. Gómez overall: 82
# name: J. Kimmich overall: 81
# name: S. Rudy overall: 81
# name: J. Brandt overall: 80
# name: J. Hector overall: 80
# name: M. Ginter overall: 78
# name: M. Ginter overall: 78
# name: F. Kroos overall: 73
#
# Senegal has players: 23
# name: S. Mané overall: 84
# name: K. Koulibaly overall: 84
# name: I. Gueye overall: 83
# name: S. Sané overall: 79
# name: K. Mbodj overall: 78
# name: K. Mbodj overall: 78
# name: A. N'Diaye overall: 78
# name: Badou Ndiaye overall: 77
# name: L. Sané overall: 77
# name: M. Diouf overall: 77
# name: C. N'Doye overall: 76
# name: D. Sakho overall: 75
# name: M. Konaté overall: 74
# name: I. Sarr overall: 73
# name: A. Gomis overall: 73
# name: M. Diallo overall: 72
# name: B. Sarr overall: 71
# name: P. Sané overall: 71
# name: D. N'Doye overall: 71
# name: I. Sarr overall: 71
# name: A. Diallo overall: 70
# name: V. Sané overall: 70
# name: A. Mbengue overall: 68
#
# South Korea has players: 23
# name: Dummy boy overall: 65
# name: Almost a dummy boy overall: 65
# name: Almost a dummy boy overall: 65
# name: Almost a dummy boy overall: 65
# name: Almost a dummy boy overall: 65
# name: Almost a dummy boy overall: 65
# name: Almost a dummy boy overall: 65
# name: Almost a dummy boy overall: 65
# name: Almost a dummy boy overall: 65
# name: Almost a dummy boy overall: 65
# name: Almost a dummy boy overall: 65
# name: Almost a dummy boy overall: 65
# name: Almost a dummy boy overall: 65
# name: Almost a dummy boy overall: 65
# name: Almost a dummy boy overall: 65
# name: Almost a dummy boy overall: 65
# name: Almost a dummy boy overall: 65
# name: Almost a dummy boy overall: 65
# name: Almost a dummy boy overall: 65
# name: Almost a dummy boy overall: 65
# name: Almost a dummy boy overall: 65
# name: Almost a dummy boy overall: 65
# name: Almost a dummy boy overall: 65
#
# Morocco has players: 23
# name: H. Ziyech overall: 81
# name: Y. Belhanda overall: 81
# name: K. El Ahmadi overall: 80
# name: N. Amrabat overall: 79
# name: N. Dirar overall: 76
# name: R. Saïss overall: 76
# name: F. Fajr overall: 75
# name: S. Amrabat overall: 74
# name: A. Bouhaddouz overall: 73
# name: Manuel da Costa overall: 72
# name: Y. Ait Bennasser overall: 72
# name: K. Boutaïb overall: 71
# name: Y. Bounou overall: 71
# name: A. Harit overall: 71
# name: A. Hakimi overall: 71
# name: Y. En-Nesyri overall: 69
# name: H. Mendyl overall: 63
# name: Almost a dummy boy overall: 73
# name: Almost a dummy boy overall: 73
# name: Almost a dummy boy overall: 73
# name: Almost a dummy boy overall: 73
# name: Almost a dummy boy overall: 73
# name: Almost a dummy boy overall: 73
#
# Egypt has players: 23
# name: M. Salah overall: 83
# name: M. Elneny overall: 77
# name: Kahraba overall: 75
# name: R. Sobhi overall: 74
# name: A. El-Shenawy overall: 73
# name: A. Elmohamady overall: 72
# name: A. Warda overall: 71
# name: Shikabala overall: 70
# name: O. Gaber overall: 69
# name: S. Ekramy overall: 69
# name: S. Morsy overall: 68
# name: A. Gabr overall: 67
# name: T. Hamed overall: 66
# name: I. Salah overall: 66
# name: M. Mohsen overall: 65
# name: Almost a dummy boy overall: 71
# name: Almost a dummy boy overall: 71
# name: Almost a dummy boy overall: 71
# name: Almost a dummy boy overall: 71
# name: Almost a dummy boy overall: 71
# name: Almost a dummy boy overall: 71
# name: Almost a dummy boy overall: 71
# name: Almost a dummy boy overall: 71
#
# Australia has players: 23
# name: M. Ryan overall: 77
# name: B. Jones overall: 77
# name: A. Mooy overall: 77
# name: T. Sainsbury overall: 74
# name: M. Milligan overall: 74
# name: J. Maclaren overall: 73
# name: A. Behich overall: 73
# name: R. Kruse overall: 72
# name: M. Leckie overall: 72
# name: M. Luongo overall: 71
# name: J. Irvine overall: 71
# name: J. Risdon overall: 70
# name: M. Degenek overall: 70
# name: T. Cahill overall: 70
# name: D. Vukovic overall: 70
# name: M. Jurman overall: 69
# name: J. Meredith overall: 68
# name: D. Petratos overall: 66
# name: A. Nabbout overall: 65
# name: D. Ryan overall: 59
# name: D. Arzani overall: 58
# name: K. Petratos overall: 57
# name: Almost a dummy boy overall: 69
#
# Poland has players: 23
# name: K. Glik overall: 85
# name: L. Piszczek overall: 83
# name: W. Szczęsny overall: 82
# name: G. Krychowiak overall: 81
# name: P. Zieliński overall: 80
# name: L. Fabiański overall: 80
# name: A. Milik overall: 79
# name: L. Teodorczyk overall: 78
# name: K. Grosicki overall: 76
# name: J. Błaszczykowski overall: 76
# name: M. Pazdan overall: 76
# name: K. Linetty overall: 75
# name: B. Białkowski overall: 74
# name: B. Bereszyński overall: 73
# name: J. Góralski overall: 73
# name: A. Jędrzejczyk overall: 73
# name: M. Rybus overall: 72
# name: Thiago Cionek overall: 71
# name: S. Peszko overall: 69
# name: J. Bednarek overall: 68
# name: D. Kownacki overall: 68
# name: R. Kurzawa overall: 67
# name: D. Zieliński overall: 56
#
# Switzerland has players: 23
# name: R. Bürki overall: 84
# name: Y. Sommer overall: 83
# name: G. Xhaka overall: 82
# name: X. Shaqiri overall: 82
# name: R. Rodríguez overall: 81
# name: B. Džemaili overall: 78
# name: V. Behrami overall: 77
# name: M. Lang overall: 77
# name: B. Embolo overall: 76
# name: Gelson Fernandes overall: 76
# name: R. Freuler overall: 75
# name: S. Zuber overall: 75
# name: F. Schär overall: 75
# name: Y. Mvogo overall: 75
# name: N. Elvedi overall: 74
# name: J. Drmić overall: 74
# name: H. Seferović overall: 74
# name: F. Moubandje overall: 74
# name: J. Djourou overall: 73
# name: M. Akanji overall: 72
# name: D. Zakaria overall: 72
# name: E. Fernandes overall: 69
# name: F. Rodríguez overall: 68
#
# Belgium has players: 23
# name: E. Hazard overall: 90
# name: K. De Bruyne overall: 89
# name: T. Courtois overall: 89
# name: R. Lukaku overall: 86
# name: T. Alderweireld overall: 86
# name: D. Mertens overall: 86
# name: Y. Carrasco overall: 85
# name: J. Vertonghen overall: 85
# name: V. Kompany overall: 85
# name: M. Dembélé overall: 83
# name: A. Witsel overall: 82
# name: T. Meunier overall: 81
# name: S. Mignolet overall: 81
# name: Y. Tielemans overall: 80
# name: M. Batshuayi overall: 80
# name: T. Hazard overall: 80
# name: L. Dendoncker overall: 79
# name: M. Fellaini overall: 79
# name: N. Chadli overall: 78
# name: T. Vermaelen overall: 78
# name: K. Casteels overall: 78
# name: J. Lukaku overall: 77
# name: A. Januzaj overall: 77
#
# Panama has players: 23
# name: A. Machado overall: 71
# name: A. Godoy overall: 71
# name: G. Gómez overall: 70
# name: R. Torres overall: 70
# name: G. Torres overall: 68
# name: A. Cooper overall: 67
# name: H. Cummings overall: 66
# name: F. Escobar overall: 65
# name: M. Murillo overall: 64
# name: L. Ovalle overall: 57
# name: Almost a dummy boy overall: 66
# name: Almost a dummy boy overall: 66
# name: Almost a dummy boy overall: 66
# name: Almost a dummy boy overall: 66
# name: Almost a dummy boy overall: 66
# name: Almost a dummy boy overall: 66
# name: Almost a dummy boy overall: 66
# name: Almost a dummy boy overall: 66
# name: Almost a dummy boy overall: 66
# name: Almost a dummy boy overall: 66
# name: Almost a dummy boy overall: 66
# name: Almost a dummy boy overall: 66
# name: Almost a dummy boy overall: 66
#
# England has players: 23
# name: D. Alli overall: 84
# name: G. Cahill overall: 84
# name: K. Walker overall: 83
# name: R. Sterling overall: 82
# name: E. Dier overall: 82
# name: J. Henderson overall: 82
# name: D. Rose overall: 82
# name: J. Vardy overall: 81
# name: J. Butland overall: 81
# name: M. Rashford overall: 80
# name: D. Welbeck overall: 80
# name: J. Stones overall: 79
# name: P. Jones overall: 79
# name: J. Lingard overall: 78
# name: J. Lingard overall: 78
# name: K. Trippier overall: 78
# name: F. Delph overall: 77
# name: J. Pickford overall: 77
# name: H. Maguire overall: 77
# name: A. Young overall: 75
# name: D. Jones overall: 71
# name: B. Jones overall: 71
# name: R. Loftus-Cheek overall: 70
#
# Tunisia has players: 23
# name: Y. Benalouane overall: 75
# name: E. Skhiri overall: 74
# name: S. Ben Youssef overall: 72
# name: N. Sliti overall: 72
# name: B. Srarfi overall: 68
# name: O. Haddadi overall: 66
# name: D. Bronn overall: 65
# name: F. Ben Mustapha overall: 63
# name: Almost a dummy boy overall: 69
# name: Almost a dummy boy overall: 69
# name: Almost a dummy boy overall: 69
# name: Almost a dummy boy overall: 69
# name: Almost a dummy boy overall: 69
# name: Almost a dummy boy overall: 69
# name: Almost a dummy boy overall: 69
# name: Almost a dummy boy overall: 69
# name: Almost a dummy boy overall: 69
# name: Almost a dummy boy overall: 69
# name: Almost a dummy boy overall: 69
# name: Almost a dummy boy overall: 69
# name: Almost a dummy boy overall: 69
# name: Almost a dummy boy overall: 69
# name: Almost a dummy boy overall: 69
#
# Costa Rica has players: 23
# name: K. Navas overall: 85
# name: O. Duarte overall: 77
# name: J. Campbell overall: 77
# name: G. González overall: 75
# name: K. Waston overall: 74
# name: C. Gamboa overall: 72
# name: B. Oviedo overall: 72
# name: F. Calvo overall: 71
# name: C. Bolaños overall: 71
# name: B. Acosta overall: 71
# name: R. Wallace overall: 68
# name: M. Ureña overall: 68
# name: Y. Tejeda overall: 68
# name: J. Venegas overall: 67
# name: Almost a dummy boy overall: 72
# name: Almost a dummy boy overall: 72
# name: Almost a dummy boy overall: 72
# name: Almost a dummy boy overall: 72
# name: Almost a dummy boy overall: 72
# name: Almost a dummy boy overall: 72
# name: Almost a dummy boy overall: 72
# name: Almost a dummy boy overall: 72
# name: Almost a dummy boy overall: 72
#
# France has players: 23
# name: A. Griezmann overall: 88
# name: N. Kanté overall: 87
# name: P. Pogba overall: 87
# name: R. Varane overall: 85
# name: B. Matuidi overall: 85
# name: K. Mbappé overall: 83
# name: O. Dembélé overall: 83
# name: T. Lemar overall: 83
# name: S. Umtiti overall: 83
# name: C. Tolisso overall: 82
# name: N. Fekir overall: 82
# name: F. Thauvin overall: 82
# name: O. Giroud overall: 82
# name: S. Mandanda overall: 82
# name: A. Rami overall: 81
# name: D. Sidibé overall: 79
# name: A. Areola overall: 79
# name: B. Mendy overall: 78
# name: P. Kimpembe overall: 77
# name: L. Hernández overall: 77
# name: N. Mendy overall: 76
# name: M. Dembélé overall: 75
# name: T. Hernández overall: 75
#
# Nigeria has players: 23
# name: V. Moses overall: 79
# name: O. Ndidi overall: 77
# name: A. Musa overall: 76
# name: L. Balogun overall: 75
# name: K. Iheanacho overall: 75
# name: A. Iwobi overall: 74
# name: O. Onazi overall: 74
# name: J. Obi overall: 73
# name: P. Etebo overall: 73
# name: K. Omeruo overall: 72
# name: E. Echiéjilé overall: 71
# name: W. Troost-Ekong overall: 71
# name: C. Awaziem overall: 71
# name: S. Abdullahi overall: 69
# name: T. Ebuehi overall: 66
# name: I. Abdullahi overall: 64
# name: Almost a dummy boy overall: 72
# name: Almost a dummy boy overall: 72
# name: Almost a dummy boy overall: 72
# name: Almost a dummy boy overall: 72
# name: Almost a dummy boy overall: 72
# name: Almost a dummy boy overall: 72
# name: Almost a dummy boy overall: 72
#
# Peru has players: 23
# name: J. Farfán overall: 78
# name: A. Carrillo overall: 77
# name: P. Hurtado overall: 76
# name: R. Ruidíaz overall: 76
# name: P. Gallese overall: 74
# name: A. Rodríguez overall: 73
# name: R. Tapia overall: 72
# name: L. Advíncula overall: 72
# name: Y. Yotún overall: 71
# name: A. Polo overall: 69
# name: J. Carvallo overall: 68
# name: C. Ramos overall: 67
# name: M. Araujo overall: 67
# name: A. Corzo overall: 65
# name: P. Aquino overall: 65
# name: W. Cartagena overall: 64
# name: E. Flores overall: 63
# name: N. Loyola overall: 63
# name: Almost a dummy boy overall: 70
# name: Almost a dummy boy overall: 70
# name: Almost a dummy boy overall: 70
# name: Almost a dummy boy overall: 70
# name: Almost a dummy boy overall: 70
#
# Argentina has players: 23
# name: G. Higuaín overall: 90
# name: S. Agüero overall: 89
# name: P. Dybala overall: 88
# name: A. Di María overall: 85
# name: N. Otamendi overall: 83
# name: E. Banega overall: 83
# name: L. Biglia overall: 83
# name: J. Mascherano overall: 83
# name: M. Rojo overall: 82
# name: F. Fazio overall: 82
# name: E. Salvio overall: 80
# name: M. Acuña overall: 79
# name: N. Tagliafico overall: 79
# name: C. Ansaldi overall: 79
# name: W. Caballero overall: 79
# name: E. Pérez overall: 78
# name: P. Pérez overall: 77
# name: F. Armani overall: 77
# name: F. Higuaín overall: 77
# name: G. Mercado overall: 76
# name: C. Pavón overall: 75
# name: G. Lo Celso overall: 74
# name: D. Pérez overall: 73
#
# Colombia has players: 23
# name: J. Rodríguez overall: 86
# name: C. Bacca overall: 82
# name: J. Cuadrado overall: 82
# name: D. Sánchez overall: 81
# name: L. Muriel overall: 80
# name: J. Murillo overall: 79
# name: D. Ospina overall: 79
# name: J. Izquierdo overall: 78
# name: D. Zapata overall: 78
# name: J. Quintero overall: 77
# name: C. Sánchez overall: 77
# name: S. Arias overall: 77
# name: O. Murillo overall: 76
# name: A. Aguilar overall: 75
# name: C. Vargas overall: 75
# name: J. Lerma overall: 75
# name: J. Cuadrado overall: 74
# name: W. Barrios overall: 74
# name: F. Uribe overall: 74
# name: M. Uribe overall: 73
# name: F. Díaz overall: 73
# name: A. Rodríguez overall: 73
# name: M. Barrios overall: 73
#
# Iceland has players: 23
# name: G. Sigurðsson overall: 82
# name: A. Finnbogason overall: 76
# name: E. Hallfreðsson overall: 75
# name: J. Guðmundsson overall: 73
# name: B. Bjarnason overall: 73
# name: B. Sigurðarson overall: 73
# name: R. Sigurðsson overall: 72
# name: S. Ingason overall: 72
# name: O. Skúlason overall: 70
# name: K. Árnason overall: 70
# name: A. Traustason overall: 70
# name: J. Böðvarsson overall: 69
# name: R. Gíslason overall: 68
# name: H. Magnússon overall: 68
# name: A. Skúlason overall: 68
# name: H. Halldórsson overall: 67
# name: B. Sævarsson overall: 66
# name: A. Guðmundsson overall: 66
# name: A. Sigurðarson overall: 66
# name: K. Finnbogason overall: 65
# name: R. Rúnarsson overall: 64
# name: K. Sigurðsson overall: 62
# name: A. Sigurðsson overall: 53
#
# Russia has players: 23
# name: Mário Fernandes overall: 81
# name: A. Dzagoev overall: 80
# name: F. Smolov overall: 80
# name: I. Smolnikov overall: 79
# name: A. Samedov overall: 79
# name: D. Cheryshev overall: 78
# name: D. Cheryshev overall: 78
# name: S. Ignashevich overall: 78
# name: A. Dzyuba overall: 78
# name: R. Zobnin overall: 77
# name: Y. Zhirkov overall: 76
# name: A. Golovin overall: 76
# name: Y. Gazinskiy overall: 75
# name: A. Miranchuk overall: 74
# name: D. Kuzyaev overall: 74
# name: V. Gabulov overall: 74
# name: F. Kudryashov overall: 73
# name: I. Kutepov overall: 73
# name: V. Granat overall: 72
# name: A. Miranchuk overall: 68
# name: G. Gabulov overall: 67
# name: Almost a dummy boy overall: 75
# name: Almost a dummy boy overall: 75
#
# Portugal has players: 23
# name: Pepe overall: 86
# name: Bernardo Silva overall: 84
# name: João Mário overall: 83
# name: William Carvalho overall: 83
# name: Danilo Pereira overall: 83
# name: A. Lopes overall: 83
# name: Adrien Silva overall: 83
# name: Rui Patrício overall: 83
# name: Quaresma overall: 83
# name: João Moutinho overall: 82
# name: Gelson Martins overall: 81
# name: R. Guerreiro overall: 81
# name: Ricardo Pereira overall: 80
# name: Manuel Fernandes overall: 80
# name: Cédric overall: 79
# name: José Fonte overall: 79
# name: André Silva overall: 78
# name: Bruno Fernandes overall: 78
# name: Bruno Alves overall: 78
# name: Miguel Lopes overall: 78
# name: Bruno Fernandes overall: 78
# name: Mário Rui overall: 77
# name: Rony Lopes overall: 77
#
# Denmark has players: 23
# name: C. Eriksen overall: 87
# name: K. Schmeichel overall: 83
# name: A. Christensen overall: 81
# name: J. Vestergaard overall: 79
# name: N. Jørgensen overall: 79
# name: M. Krohn-Dehli overall: 79
# name: K. Dolberg overall: 78
# name: M. Braithwaite overall: 77
# name: Y. Poulsen overall: 76
# name: L. Lerager overall: 75
# name: J. Lössl overall: 75
# name: V. Fischer overall: 75
# name: M. Jørgensen overall: 75
# name: P. Sisto overall: 74
# name: F. Rønnow overall: 73
# name: A. Cornelius overall: 73
# name: J. Poulsen overall: 71
# name: H. Dalsgaard overall: 71
# name: W. Kvist overall: 70
# name: K. Larsen overall: 70
# name: J. Knudsen overall: 69
# name: J. Stryger Larsen overall: 69
# name: L. Christensen overall: 68
#
# Spain has players: 23
# name: De Gea overall: 90
# name: Thiago overall: 88
# name: David Silva overall: 87
# name: Piqué overall: 87
# name: Iniesta overall: 87
# name: Isco overall: 86
# name: Sergio Busquets overall: 86
# name: Diego Costa overall: 86
# name: Jordi Alba overall: 85
# name: Azpilicueta overall: 85
# name: Marco Asensio overall: 84
# name: Carvajal overall: 84
# name: Koke overall: 84
# name: Iago Aspas overall: 83
# name: José Reina overall: 83
# name: Lucas Vázquez overall: 82
# name: Saúl overall: 82
# name: Arrizabalaga overall: 80
# name: Nacho Monreal overall: 80
# name: Jaume Costa overall: 79
# name: Rodrigo overall: 78
# name: Rodrigo overall: 78
# name: Víctor Vázquez overall: 76
#
# Mexico has players: 23
# name: J. Hernández overall: 82
# name: C. Vela overall: 82
# name: J. Corona overall: 81
# name: H. Moreno overall: 80
# name: A. Guardado overall: 80
# name: J. dos Santos overall: 80
# name: M. Fabián overall: 79
# name: G. dos Santos overall: 79
# name: H. Herrera overall: 79
# name: G. Ochoa overall: 79
# name: H. Lozano overall: 78
# name: R. Jiménez overall: 78
# name: M. Layún overall: 78
# name: J. Aquino overall: 77
# name: E. Hernández overall: 77
# name: O. Peralta overall: 76
# name: E. Gutiérrez overall: 76
# name: J. Corona overall: 76
# name: J. Hernández overall: 75
# name: H. Ayala overall: 75
# name: C. Salcedo overall: 74
# name: E. Hernández overall: 72
# name: I. Jiménez overall: 72
#
# Croatia has players: 23
# name: I. Rakitić overall: 87
# name: D. Subašić overall: 85
# name: I. Perišić overall: 84
# name: M. Mandžukić overall: 83
# name: M. Kovačić overall: 82
# name: V. Ćorluka overall: 82
# name: A. Kramarić overall: 81
# name: M. Brozović overall: 81
# name: D. Lovren overall: 81
# name: N. Kalinić overall: 81
# name: S. Vrsaljko overall: 79
# name: M. Badelj overall: 78
# name: M. Badelj overall: 78
# name: L. Kalinić overall: 77
# name: T. Jedvaj overall: 76
# name: M. Pjaca overall: 76
# name: I. Strinić overall: 75
# name: A. Rebić overall: 72
# name: D. Ćaleta-Car overall: 71
# name: D. Lovren overall: 58
# name: D. Kovačić overall: 58
# name: Almost a dummy boy overall: 77
# name: Almost a dummy boy overall: 77
#
# Uruguay has players: 23
# name: L. Suárez overall: 92
# name: E. Cavani overall: 87
# name: J. Giménez overall: 83
# name: F. Muslera overall: 82
# name: S. Coates overall: 81
# name: M. Campaña overall: 79
# name: M. Vecino overall: 78
# name: D. Laxalt overall: 78
# name: D. Laxalt overall: 78
# name: C. Stuani overall: 77
# name: C. Sánchez overall: 77
# name: M. Cáceres overall: 77
# name: C. Rodríguez overall: 75
# name: L. Torreira overall: 75
# name: D. Suárez overall: 74
# name: J. Urretaviscaya overall: 74
# name: M. Gómez overall: 73
# name: D. Rodríguez overall: 73
# name: A. Silva overall: 73
# name: G. Silva overall: 72
# name: J. Rodríguez overall: 72
# name: M. Silva overall: 71
# name: N. Nández overall: 70
#
# Saudi Arabia has players: 23
# name: O. Hawsawi overall: 75
# name: M. Hawsawi overall: 74
# name: A. Asiri overall: 71
# name: M. Kanno overall: 67
# name: H. Bahebri overall: 66
# name: O. Hawsawi overall: 58
# name: S. Otayf overall: 58
# name: M. Asiri overall: 56
# name: S. Hawsawi overall: 55
# name: M. Asiri overall: 55
# name: A. Al Assiri overall: 55
# name: H. Hawsawi overall: 52
# name: Almost a dummy boy overall: 61
# name: Almost a dummy boy overall: 61
# name: Almost a dummy boy overall: 61
# name: Almost a dummy boy overall: 61
# name: Almost a dummy boy overall: 61
# name: Almost a dummy boy overall: 61
# name: Almost a dummy boy overall: 61
# name: Almost a dummy boy overall: 61
# name: Almost a dummy boy overall: 61
# name: Almost a dummy boy overall: 61
# name: Almost a dummy boy overall: 61
#
# Iran has players: 23
# name: S. Azmoun overall: 77
# name: A. Jahanbakhsh overall: 75
# name: M. Mohammadi overall: 73
# name: K. Ansarifard overall: 73
# name: R. Ghoochannejhad overall: 72
# name: S. Ghoddos overall: 71
# name: R. Rezaeian overall: 70
# name: S. Ezatolahi overall: 66
# name: A. Abedzadeh overall: 62
# name: Almost a dummy boy overall: 71
# name: Almost a dummy boy overall: 71
# name: Almost a dummy boy overall: 71
# name: Almost a dummy boy overall: 71
# name: Almost a dummy boy overall: 71
# name: Almost a dummy boy overall: 71
# name: Almost a dummy boy overall: 71
# name: Almost a dummy boy overall: 71
# name: Almost a dummy boy overall: 71
# name: Almost a dummy boy overall: 71
# name: Almost a dummy boy overall: 71
# name: Almost a dummy boy overall: 71
# name: Almost a dummy boy overall: 71
# name: Almost a dummy boy overall: 71
